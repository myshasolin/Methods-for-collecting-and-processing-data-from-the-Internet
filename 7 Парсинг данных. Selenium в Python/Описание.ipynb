# %% [markdown]
# Ход действий такой: логинюсь, захожу на почту, собираю ссылки на письма, проверяя их и останавливаясь на последнем письме. И уже потом вторым циклом делаю get-запрос к каждому письму, проваливаюсь в него и из тела письма собираю информацию:
#
# - **sender** – отправитель
# - **email_sender** – почта отправителя
# - **email_date** – дата письма
# - **email_title** – заголовок письма
# - **link** – ссылка на письмо
#
# Способ, на мой взгляд, медленный, но он хорош тем, что собрать таким способом из письма можно всё что угодно.
#
# Логин и пароль к почте положил в .env-файл, обращаюсь к ним через модуль dotenv
#
# А собранную из писем информацию складываю с MongoDB в коллекцию mail_ru, JSON-файл с ней прикладываю

# %% [markdown]
# # Вариант II
#
# Написать программу, которая собирает товары «В тренде» с сайта техники mvideo и складывает данные в БД. Сайт можно выбрать и свой. Главный критерий выбора: динамически загружаемые товары

# %% [markdown]
# На сайте МВидео опускаюсь до раздела «Самые просматриваемые» и, как только он появляется, забираю из него:
#
# - **name** – название товара
# - **price** – цену товара (тип int)
# - **link** – ссылку на товар.
#
# Собранную инфу складываю в MongoDB в коллекцию mvideo_most_viewed_products, в которой ив качестве "_id" выступает ссылка на письмо и дубли товаров, соответственно, не добавляются.
#
# Файл с собранной в JSON инфой тоже к дз прикладываю

# %% [markdown]
# # Вариант I
#
# Написать программу, которая собирает входящие письма из своего или тестового почтового ящика и сложить данные о письмах в базу данных (от кого, дата отправки, тема письма, текст письма полный)
